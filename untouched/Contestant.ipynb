# %%
# Contestant Techniques 
from sklearn.cluster import AgglomerativeClustering
import numpy
from igraph import *
import igraph
import random
import numpy as np
import pandas as pd
from sklearn.metrics.cluster import adjusted_rand_score

path = "/Users/mcdicjh2/Desktop/gecco22/"

for it in range(0,30):

    # Read in graph and associated data
    g_org = Graph.Read_Edgelist(path+"Graph"+str(it)+".dat")
    truth = pd.read_csv(path+"Graph"+str(it)+".truth.dat", sep=',',header=None)
    groundtruth=truth.iloc[:, 1].values.tolist()
    v = pd.read_csv(path+"Graph"+str(it)+".vertices.dat", sep=',',header=None)
    vertices=v.iloc[:, 1].values.tolist()
    edges = g_org.get_edgelist()
    
    # Generate Bipartite graph
    g3 = Graph.Bipartite(vertices, edges)
    n_var = len(vertices)
    lower = vertices.count(0) 


    c= g3.clusters()  # This should always be 1 one now
    g1, g2 = g3.bipartite_projection(multiplicity=True)

    # Run Multi-Level algorithm (not implemented in igraph package)
    multilevel_result = pd.DataFrame(columns=['k','m','m1','m2','ari'])
    test1 = g1.community_multilevel()
    test2 = g2.community_multilevel()

    # Cluster assignment from each projection
    assignment=test1.membership+test2.membership


    k1=max(test1.membership)+1
    k2=max(test2.membership)+1
    d = numpy.zeros(shape=(k1+k2,k1+k2))


    # Calculate dissimilarity matrix between communities
    for ei in range(0,len(edges)):
        #print(edges[ei],edges[ei][0],edges[ei][1])
        index1=assignment[edges[ei][0]]
        index2=k1+assignment[edges[ei][1]]
       # print(index1,index2)
        d[index1][index2]=d[index1][index2]+1
        d[index2][index1]=d[index2][index1]+1

    for d1 in range(0,k1+k2):
        for d2 in range(0,k1+k2):
            d[d1][d2] = 1.0/(1.0+d[d1][d2])
        d[d1][d1] = 0


    ctr=0
    for k in range(len(c),k1+k2):
  
        # Run hierarchical clustering on communities
        clustering = AgglomerativeClustering(n_clusters=k,linkage='average',affinity='precomputed').fit(d)
        labels = clustering.labels_


        newlabels = np.empty(n_var)
        newlabels.fill(0)

        for v in range(0,lower):
            newlabels[v] = labels[assignment[v]]

        for v in range(lower,n_var):
            newlabels[v] = labels[k1+assignment[v]]


        m3 = g3.modularity(newlabels)
        m1 = g1.modularity(newlabels[0:lower],weights=g1.es['weight'])
        m2 = g2.modularity(newlabels[lower:n_var],weights=g2.es['weight'])
        ari = adjusted_rand_score(groundtruth,newlabels)
        multilevel_result.loc[ctr] = k, m3, m1, m2, ari
        ctr=ctr+1


    # Run FastGreedy and Comunity Edge for comparison

    communityedge_result = pd.DataFrame(columns=['k','m','m1','m2','ari'])
    communityedge_res = g3.community_edge_betweenness()

    walktrap_result = pd.DataFrame(columns=['k','m','m1','m2','ari'])
    walktrap_res = g3.community_walktrap()

    fastgreedy_result = pd.DataFrame(columns=['k','m','m1','m2','ari'])
    fastgreedy_res = g3.community_fastgreedy()


   
    for i in range (0,1):
        for k in range(len(c),min(len(c)+15,n_var)):
            
            
            test = fastgreedy_res.as_clustering(k)
            m3 = g3.modularity(test)

            m1 = g1.modularity(test.membership[0:lower],weights=g1.es['weight'])
            m2 = g2.modularity(test.membership[lower:n_var],weights=g2.es['weight'])

            ari = adjusted_rand_score(groundtruth,test.membership)
            fastgreedy_result.loc[i*30+k] = k, m3, m1, m2, ari

            test = communityedge_res.as_clustering(k)
            m3 = g3.modularity(test)

            m1 = g1.modularity(test.membership[0:lower],weights=g1.es['weight'])
            m2 = g2.modularity(test.membership[lower:n_var],weights=g2.es['weight'])

            ari = adjusted_rand_score(groundtruth,test.membership)
            communityedge_result.loc[i*30+k] = k, m3, m1, m2, ari

            test = walktrap_res.as_clustering(k)
            m3 = g3.modularity(test)

            m1 = g1.modularity(test.membership[0:lower],weights=g1.es['weight'])
            m2 = g2.modularity(test.membership[lower:n_var],weights=g2.es['weight'])

            ari = adjusted_rand_score(groundtruth,test.membership)
            walktrap_result.loc[i*30+k] = k, m3, m1, m2, ari
        
    multilevel_result.to_csv(path+"Graph"+str(it)+".multilevel.csv")
    communityedge_result.to_csv(path+"Graph"+str(it)+".communityedge.csv")
    walktrap_result.to_csv(path+"Graph"+str(it)+".walktrap.csv")
    fastgreedy_result.to_csv(path+"Graph"+str(it)+".fastgreedy.csv")

# %%
# Yet another contestant technique
# Use of BRIM package for comparison

import condor
import pandas as pd


for it in range(0,30):


    # Read in graph and associated data
    g_org = Graph.Read_Edgelist(path+"Graph"+str(it)+".dat")
    truth = pd.read_csv(path+"Graph"+str(it)+".truth.dat", sep=',',header=None)
    groundtruth=truth.iloc[:, 1].values.tolist()
    v = pd.read_csv(path+"Graph"+str(it)+".vertices.dat", sep=',',header=None)
    vertices=v.iloc[:, 1].values.tolist()
    edges = g_org.get_edgelist()

    g3 = Graph.Bipartite(vertices, edges)
    n_var = len(vertices)
    lower = vertices.count(0)

    g1, g2 = g3.bipartite_projection(multiplicity=True)
    
    el = g3.get_edgelist()
    net = pd.DataFrame(el)



    brim_result = pd.DataFrame(columns=['k','ari','m1','m2','m'])

    for i in range (0,1):

        co = condor.condor_object(net)
        co = condor.initial_community(co)
        co = condor.brim(co)

        n_l = vertices.count(0)
        
        groundtruth1 = groundtruth[0:n_l]
        groundtruth2 = groundtruth[n_l:n_var]
        

        output1=co["reg_memb"]
        output1=output1["com"].tolist()
        output2 = co["tar_memb"]
        output2=output2["com"].tolist()

        
        
        ari = adjusted_rand_score(groundtruth1,output2)
        ari2 = adjusted_rand_score(groundtruth2,output1)
        output3=output2+output1
        #print(output)
        ari3 = adjusted_rand_score(groundtruth,output3)
        print(max(output3)+1,ari,ari2,ari3)

        m = g3.modularity(output3)
        m1 = g1.modularity(output2,weights=g1.es['weight'])#
        m2 = g2.modularity(output1,weights=g2.es['weight'])

        k = (max(output3)+1)
        brim_result.loc[i] = k, ari3, m1, m2, m
        
    brim_result.to_csv(path+"Graph"+str(it)+".brim.csv")
# Out:
# Unweighted network. Weights initialized as 1.
# Condor object built in 0.0030732154846191406
# Initial community structure computed in  0.0007450580596923828 . Modularity =  0.5091625
# Matrices computed in 0.0012791156768798828
# 0.5308999999999999
# 0.5310499999999999
# 0.5310499999999999
# 10 0.10201912858660998 0.07981148506736337 0.0942790024764206
# Unweighted network. Weights initialized as 1.
# Condor object built in 0.003574848175048828
# Initial community structure computed in  0.0010211467742919922 . Modularity =  0.49841250000000004
# Matrices computed in 0.0015869140625
# 0.50985
# 0.50985
# 9 0.07890051983194475 0.05576503708673996 0.07313085335253808
# Unweighted network. Weights initialized as 1.
# Condor object built in 0.0023589134216308594
# Initial community structure computed in  0.001104116439819336 . Modularity =  0.4892875000000001
# Matrices computed in 0.0015468597412109375
# 0.50885
# 0.50915
# 0.50915
# 8 0.0333796940194715 0.012141565777401993 0.028402190525042958
# Unweighted network. Weights initialized as 1.
# Condor object built in 0.0030260086059570312
# Initial community structure computed in  0.0008137226104736328 . Modularity =  0.48372499999999985
# Matrices computed in 0.0020449161529541016
# 0.49612500000000004
# 0.49612500000000004
# 8 0.09707654763683449 0.08729971022123138 0.1017693400490766
# Unweighted network. Weights initialized as 1.
# Condor object built in 0.003366708755493164
# Initial community structure computed in  0.0006327629089355469 . Modularity =  0.5031436007111751
# Matrices computed in 0.0017240047454833984
# 0.5045221469246823
# 0.5045221469246823
# 9 0.05969924812030073 0.06900370592928176 0.07676231966410962
# Unweighted network. Weights initialized as 1.
# Condor object built in 0.0023720264434814453
# Initial community structure computed in  0.0006961822509765625 . Modularity =  0.4886108560350984
# Matrices computed in 0.0015921592712402344
# 0.5085195388225693
# 0.5099479644934192
# 0.5099479644934192
# 8 0.08702869934854238 0.08267699016597696 0.0915612931723358
# Unweighted network. Weights initialized as 1.
# Condor object built in 0.0030570030212402344
# Initial community structure computed in  0.0009748935699462891 . Modularity =  0.48302500000000004
# Matrices computed in 0.0017108917236328125
# 0.492525
# 0.4926
# 0.4926
# 8 0.11183027687882058 0.06099033049135336 0.08878031391215911
# Unweighted network. Weights initialized as 1.
# Condor object built in 0.003719329833984375
# Initial community structure computed in  0.0008199214935302734 . Modularity =  0.525225
# Matrices computed in 0.0015590190887451172
# 0.5346500000000001
# 0.5346500000000001
# 9 0.01757959052417194 0.04901447340359077 0.047977202776690396
# Unweighted network. Weights initialized as 1.
# Condor object built in 0.0019059181213378906
# Initial community structure computed in  0.0007419586181640625 . Modularity =  0.5000757556627358
# Matrices computed in 0.002117156982421875
# 0.5059973232999168
# 0.5063508497260171
# 0.5063508497260171
# 10 0.07486970135352053 0.08179098360655739 0.08816089273219829
# Unweighted network. Weights initialized as 1.
# Condor object built in 0.002273082733154297
# Initial community structure computed in  0.0009319782257080078 . Modularity =  0.517475
# Matrices computed in 0.0014712810516357422
# 0.52735
# 0.52735
# 9 0.045888556363118144 0.06045353764810148 0.059515285277443146
# Unweighted network. Weights initialized as 1.
# Condor object built in 0.0036287307739257812
# Initial community structure computed in  0.0008368492126464844 . Modularity =  0.4870205297846013
# Matrices computed in 0.001850128173828125
# 0.5030176005656423
# 0.503345875104164
# 0.503345875104164
# 10 0.07691731388757087 0.04729407886935566 0.06180971924137264
# Unweighted network. Weights initialized as 1.
# Condor object built in 0.002727985382080078
# Initial community structure computed in  0.0008108615875244141 . Modularity =  0.4830812353223403
# Matrices computed in 0.0018267631530761719
# 0.5021842882755486
# 0.5058205600868665
# 0.5058205600868665
# 10 0.0051191491894680375 0.034330650611292 0.034566750050059936
# Unweighted network. Weights initialized as 1.
# Condor object built in 0.0028738975524902344
# Initial community structure computed in  0.0008132457733154297 . Modularity =  0.48655
# Matrices computed in 0.0018429756164550781
# 0.49247499999999994
# 0.49307499999999993
# 0.49307499999999993
# 8 0.07367821006127975 0.08122207949917365 0.08545909553837788
# Unweighted network. Weights initialized as 1.
# Condor object built in 0.002767801284790039
# Initial community structure computed in  0.0008759498596191406 . Modularity =  0.49362389838640436
# Matrices computed in 0.002244710922241211
# 0.5047094770334083
# 0.5047094770334083
# 9 0.05196917553481638 0.049327445929923566 0.059944920982567186
# Unweighted network. Weights initialized as 1.
# Condor object built in 0.003145933151245117
# Initial community structure computed in  0.0007448196411132812 . Modularity =  0.49462500000000004
# Matrices computed in 0.0015859603881835938
# 0.498025
# 0.498025
# 7 0.014882312828313876 0.03408821742309553 0.037244180564513264
# Unweighted network. Weights initialized as 1.
# Condor object built in 0.002402067184448242
# Initial community structure computed in  0.0008523464202880859 . Modularity =  0.5063125
# Matrices computed in 0.0014870166778564453
# 0.51555
# 0.51555
# 8 0.10901692011137287 0.06520337136122044 0.08908618790933717
# Unweighted network. Weights initialized as 1.
# Condor object built in 0.0021240711212158203
# Initial community structure computed in  0.0007078647613525391 . Modularity =  0.48465
# Matrices computed in 0.0014820098876953125
# 0.5111249999999999
# 0.5112
# 0.5112
# 8 0.11347729855835377 0.07420734100971094 0.09608320584189349
# Unweighted network. Weights initialized as 1.
# Condor object built in 0.002441883087158203
# Initial community structure computed in  0.0007722377777099609 . Modularity =  0.5345375
# Matrices computed in 0.001714944839477539
# 0.546025
# 0.5464249999999999
# 0.5464249999999999
# 9 0.1147052564375399 0.08764079617343001 0.10567486698732677
# Unweighted network. Weights initialized as 1.
# Condor object built in 0.0021440982818603516
# Initial community structure computed in  0.00074005126953125 . Modularity =  0.49028750000000004
# Matrices computed in 0.0014319419860839844
# 0.508775
# 0.508775
# 10 0.00905111655167297 0.02775848900672174 0.03215940540087218
# Unweighted network. Weights initialized as 1.
# Condor object built in 0.002710103988647461
# Initial community structure computed in  0.0007960796356201172 . Modularity =  0.5230044695841015
# Matrices computed in 0.0013697147369384766
# 0.5315522335294564
# 0.5321582788313426
# 0.5321582788313426
# 8 0.16985462892119357 0.08752534344630473 0.11959644995663582
# Unweighted network. Weights initialized as 1.
# Condor object built in 0.0029668807983398438
# Initial community structure computed in  0.0008819103240966797 . Modularity =  0.5160349486124088
# Matrices computed in 0.001580953598022461
# 0.5228655842024192
# 0.5228655842024192
# 8 0.033705963745682244 0.04841755264562211 0.05112456555087037
# Unweighted network. Weights initialized as 1.
# Condor object built in 0.003122091293334961
# Initial community structure computed in  0.0008509159088134766 . Modularity =  0.5314249999999998
# Matrices computed in 0.0015208721160888672
# 0.5379999999999999
# 0.5379999999999999
# 7 0.10356512672441452 0.11038458802527863 0.11768336925092863
# Unweighted network. Weights initialized as 1.
# Condor object built in 0.002927064895629883
# Initial community structure computed in  0.0010180473327636719 . Modularity =  0.4946339738895483
# Matrices computed in 0.001348257064819336
# 0.5028660892401707
# 0.5028660892401707
# 8 0.13859625528608358 0.1272334842777942 0.1324477283445999
# Unweighted network. Weights initialized as 1.
# Condor object built in 0.003256082534790039
# Initial community structure computed in  0.0010306835174560547 . Modularity =  0.47596250000000007
# Matrices computed in 0.0013651847839355469
# 0.4889
# 0.4889
# 7 0.04961005607209163 0.07506101490887632 0.0748180309028221
# Unweighted network. Weights initialized as 1.
# Condor object built in 0.003281116485595703
# Initial community structure computed in  0.0009212493896484375 . Modularity =  0.5230124999999999
# Matrices computed in 0.0024449825286865234
# 0.535925
# 0.535925
# 9 0.15091653319095924 0.09190622623614329 0.1177675322241408
# Unweighted network. Weights initialized as 1.
# Condor object built in 0.003286123275756836
# Initial community structure computed in  0.0006241798400878906 . Modularity =  0.49402499999999994
# Matrices computed in 0.0017769336700439453
# 0.5109
# 0.5148750000000001
# 0.5148750000000001
# 9 0.06338727995457126 0.05922817940958394 0.07056364412021299
# Unweighted network. Weights initialized as 1.
# Condor object built in 0.0030159950256347656
# Initial community structure computed in  0.0008089542388916016 . Modularity =  0.503875
# Matrices computed in 0.001466989517211914
# 0.5161
# 0.5162
# 0.5162
# 9 0.02723023371456986 0.023228365044143332 0.0333373298962892
# Unweighted network. Weights initialized as 1.
# Condor object built in 0.0028679370880126953
# Initial community structure computed in  0.0009090900421142578 . Modularity =  0.4832125
# Matrices computed in 0.0016467571258544922
# 0.5074
# 0.5074
# 9 0.07756842250034385 0.07556375892785491 0.0848216857964711
# Unweighted network. Weights initialized as 1.
# Condor object built in 0.0025229454040527344
# Initial community structure computed in  0.0008330345153808594 . Modularity =  0.49725
# Matrices computed in 0.0011639595031738281
# 0.50205
# 0.50205
# 7 0.10251751881650663 0.09611248336337323 0.11001457016278
# Unweighted network. Weights initialized as 1.
# Condor object built in 0.0021860599517822266
# Initial community structure computed in  0.0012259483337402344 . Modularity =  0.49270220448978563
# Matrices computed in 0.0012369155883789062
# 0.5003661523698897
# 0.5003661523698897
# 8 0.09107806691449814 0.07784728387254913 0.08960557579597658
