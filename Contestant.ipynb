# %% [markdown]
# ## Legacy Contestants | No shuffling assumption
# - This notebook generates and saves contestant results (slight modifications of original code to make pycondor work)
# - Original code is commented at the end of the notebook
# - **Needs to be run on non-shuffled data!**

# %%
# Contestant Techniques 
from sklearn.cluster import AgglomerativeClustering
import numpy
from igraph import *
import igraph
import random
import numpy as np
import pandas as pd
from sklearn.metrics.cluster import adjusted_rand_score

# path = "/Users/mcdicjh2/Desktop/gecco22/"
path = "./_temp/data_1_nonshuffled/"

for it in range(0,30):

    # Read in graph and associated data
    g_org = Graph.Read_Edgelist(path+"Graph"+str(it)+".dat")
    truth = pd.read_csv(path+"Graph"+str(it)+".truth.dat", sep=',',header=None)
    groundtruth=truth.iloc[:, 1].values.tolist()
    v = pd.read_csv(path+"Graph"+str(it)+".vertices.dat", sep=',',header=None)
    vertices=v.iloc[:, 1].values.tolist()
    edges = g_org.get_edgelist()
    
    # Generate Bipartite graph
    g3 = Graph.Bipartite(vertices, edges)
    n_var = len(vertices)
    lower = vertices.count(0) 


    c= g3.clusters()  # This should always be 1 one now
    g1, g2 = g3.bipartite_projection(multiplicity=True)

    # Run Multi-Level algorithm (not implemented in igraph package)
    multilevel_result = pd.DataFrame(columns=['k','m','m1','m2','ari'])
    test1 = g1.community_multilevel()
    test2 = g2.community_multilevel()

    # Cluster assignment from each projection
    assignment=test1.membership+test2.membership


    k1=max(test1.membership)+1
    k2=max(test2.membership)+1
    d = numpy.zeros(shape=(k1+k2,k1+k2))


    # Calculate dissimilarity matrix between communities
    for ei in range(0,len(edges)):
        #print(edges[ei],edges[ei][0],edges[ei][1])
        index1=assignment[edges[ei][0]]
        index2=k1+assignment[edges[ei][1]]
       # print(index1,index2)
        d[index1][index2]=d[index1][index2]+1
        d[index2][index1]=d[index2][index1]+1

    for d1 in range(0,k1+k2):
        for d2 in range(0,k1+k2):
            d[d1][d2] = 1.0/(1.0+d[d1][d2])
        d[d1][d1] = 0


    ctr=0
    for k in range(len(c),k1+k2):
  
        # Run hierarchical clustering on communities
        clustering = AgglomerativeClustering(n_clusters=k,linkage='average',affinity='precomputed').fit(d)
        labels = clustering.labels_


        newlabels = np.empty(n_var)
        newlabels.fill(0)

        for v in range(0,lower):
            newlabels[v] = labels[assignment[v]]

        for v in range(lower,n_var):
            newlabels[v] = labels[k1+assignment[v]]


        m3 = g3.modularity(newlabels)
        m1 = g1.modularity(newlabels[0:lower],weights=g1.es['weight'])
        m2 = g2.modularity(newlabels[lower:n_var],weights=g2.es['weight'])
        ari = adjusted_rand_score(groundtruth,newlabels)
        multilevel_result.loc[ctr] = k, m3, m1, m2, ari
        ctr=ctr+1


    # Run FastGreedy and Comunity Edge for comparison

    communityedge_result = pd.DataFrame(columns=['k','m','m1','m2','ari'])
    communityedge_res = g3.community_edge_betweenness()

    walktrap_result = pd.DataFrame(columns=['k','m','m1','m2','ari'])
    walktrap_res = g3.community_walktrap()

    fastgreedy_result = pd.DataFrame(columns=['k','m','m1','m2','ari'])
    fastgreedy_res = g3.community_fastgreedy()


   
    for i in range (0,1):
        for k in range(len(c),min(len(c)+15,n_var)):
            
            
            test = fastgreedy_res.as_clustering(k)
            m3 = g3.modularity(test)

            m1 = g1.modularity(test.membership[0:lower],weights=g1.es['weight'])
            m2 = g2.modularity(test.membership[lower:n_var],weights=g2.es['weight'])

            ari = adjusted_rand_score(groundtruth,test.membership)
            fastgreedy_result.loc[i*30+k] = k, m3, m1, m2, ari

            test = communityedge_res.as_clustering(k)
            m3 = g3.modularity(test)

            m1 = g1.modularity(test.membership[0:lower],weights=g1.es['weight'])
            m2 = g2.modularity(test.membership[lower:n_var],weights=g2.es['weight'])

            ari = adjusted_rand_score(groundtruth,test.membership)
            communityedge_result.loc[i*30+k] = k, m3, m1, m2, ari

            test = walktrap_res.as_clustering(k)
            m3 = g3.modularity(test)

            m1 = g1.modularity(test.membership[0:lower],weights=g1.es['weight'])
            m2 = g2.modularity(test.membership[lower:n_var],weights=g2.es['weight'])

            ari = adjusted_rand_score(groundtruth,test.membership)
            walktrap_result.loc[i*30+k] = k, m3, m1, m2, ari
        
    multilevel_result.to_csv(path+"Graph"+str(it)+".multilevel.csv")
    communityedge_result.to_csv(path+"Graph"+str(it)+".communityedge.csv")
    walktrap_result.to_csv(path+"Graph"+str(it)+".walktrap.csv")
    fastgreedy_result.to_csv(path+"Graph"+str(it)+".fastgreedy.csv")

# %%
# Yet another contestant technique
# Use of BRIM package for comparison

import condor
import pandas as pd
from igraph import Graph

path = "./_temp/data_1_nonshuffled/"

for it in range(0,30):


    # Read in graph and associated data
    g_org = Graph.Read_Edgelist(path+"Graph"+str(it)+".dat")
    truth = pd.read_csv(path+"Graph"+str(it)+".truth.dat", sep=',',header=None)
    groundtruth=truth.iloc[:, 1].values.tolist()
    v = pd.read_csv(path+"Graph"+str(it)+".vertices.dat", sep=',',header=None)
    vertices=v.iloc[:, 1].values.tolist()
    edges = g_org.get_edgelist()

    g3 = Graph.Bipartite(vertices, edges)
    n_var = len(vertices)
    lower = vertices.count(0)

    g1, g2 = g3.bipartite_projection(multiplicity=True)
    
    el = g3.get_edgelist()
    # net = pd.DataFrame(el)
    net = pd.DataFrame(el, dtype=str)



    brim_result = pd.DataFrame(columns=['k','ari','m1','m2','m'])

    for i in range (0,1):

        # co = condor.condor_object(net)
        # co = condor.initial_community(co)
        # co = condor.brim(co)

        co = condor.condor_object(dataframe=net)
        co.initial_community(method = "LCS", project=False) # Default parameters (passed explicitly)
        co.brim()

        n_l = vertices.count(0)
        
        groundtruth1 = groundtruth[0:n_l]
        groundtruth2 = groundtruth[n_l:n_var]
        

        # output1=co["reg_memb"]
        # output1=output1["com"].tolist()
        # output2 = co["tar_memb"]
        # output2=output2["com"].tolist()

        output1=co.reg_memb
        output1=output1["com"].tolist()
        output2 = co.tar_memb
        output2=output2["com"].tolist()

        
        
        ari = adjusted_rand_score(groundtruth1,output2)
        ari2 = adjusted_rand_score(groundtruth2,output1)
        output3=output2+output1
        #print(output)
        ari3 = adjusted_rand_score(groundtruth,output3)
        print(max(output3)+1,ari,ari2,ari3)

        m = g3.modularity(output3)
        m1 = g1.modularity(output2,weights=g1.es['weight'])#
        m2 = g2.modularity(output1,weights=g2.es['weight'])

        k = (max(output3)+1)
        brim_result.loc[i] = k, ari3, m1, m2, m
        
    brim_result.to_csv(path+"Graph"+str(it)+".brim.csv")
# Out:
# Object creation:
# Unweighted network. Weights initialized as 1.
#   Elapsed time: 0.01 sec.
# Initial community structure without projection:
# Initial modularity:  0.38955
#   Elapsed time: 0.00 sec.
# Matrix computation:
#   Elapsed time: 0.01 sec.
# BRIM:
# 0.40220000000000006
# 0.40220000000000006
#   Elapsed time: 0.00 sec.
# 3 0.7492795389048992 0.01632 0.224923544459618
# Object creation:
# Unweighted network. Weights initialized as 1.
#   Elapsed time: 0.01 sec.
# Initial community structure without projection:
# Initial modularity:  0.3900375000000001
#   Elapsed time: 0.00 sec.
# Matrix computation:
#   Elapsed time: 0.01 sec.
# BRIM:
# 0.39445
# 0.39445
#   Elapsed time: 0.00 sec.
# 3 0.8333333333333334 -0.03736825295432769 0.18501085473862175
# Object creation:
# Unweighted network. Weights initialized as 1.
#   Elapsed time: 0.01 sec.
# Initial community structure without projection:
# Initial modularity:  0.39191249999999994
#   Elapsed time: 0.00 sec.
# Matrix computation:
#   Elapsed time: 0.01 sec.
# BRIM:
# 0.404
# 0.404
#   Elapsed time: 0.00 sec.
# 2 1.0 -0.03111111111111111 0.2721072796934866
# Object creation:
# Unweighted network. Weights initialized as 1.
#   Elapsed time: 0.01 sec.
# Initial community structure without projection:
# Initial modularity:  0.4022875
#   Elapsed time: 0.00 sec.
# Matrix computation:
#   Elapsed time: 0.01 sec.
# BRIM:
# 0.40447500000000003
# 0.4128
# 0.41480000000000006
# 0.41480000000000006
#   Elapsed time: 0.00 sec.
# 3 0.6841768097373478 -0.032061558191728116 0.1563805015106903
# Object creation:
# Unweighted network. Weights initialized as 1.
#   Elapsed time: 0.01 sec.
# Initial community structure without projection:
# Initial modularity:  0.38594999999999996
#   Elapsed time: 0.00 sec.
# Matrix computation:
#   Elapsed time: 0.01 sec.
# BRIM:
# 0.38595
# 0.38595
#   Elapsed time: 0.00 sec.
# 2 1.0 -0.03111111111111111 0.2721072796934866
# Object creation:
# Unweighted network. Weights initialized as 1.
#   Elapsed time: 0.01 sec.
# Initial community structure without projection:
# Initial modularity:  0.3633625000000001
#   Elapsed time: 0.00 sec.
# Matrix computation:
#   Elapsed time: 0.01 sec.
# BRIM:
# 0.366475
# 0.366475
#   Elapsed time: 0.00 sec.
# 4 0.6838730362295607 -0.04269662921348315 0.18546259747761626
# Object creation:
# Unweighted network. Weights initialized as 1.
#   Elapsed time: 0.01 sec.
# Initial community structure without projection:
# Initial modularity:  0.38751250000000004
#   Elapsed time: 0.00 sec.
# Matrix computation:
#   Elapsed time: 0.01 sec.
# BRIM:
# 0.38870000000000005
# 0.38870000000000005
#   Elapsed time: 0.00 sec.
# 3 0.7402431222008957 -0.03073967339097022 0.218144750254842
# Object creation:
# Unweighted network. Weights initialized as 1.
#   Elapsed time: 0.01 sec.
# Initial community structure without projection:
# Initial modularity:  0.40498749999999994
#   Elapsed time: 0.00 sec.
# Matrix computation:
#   Elapsed time: 0.01 sec.
# BRIM:
# 0.40559999999999996
# 0.40559999999999996
#   Elapsed time: 0.00 sec.
# 2 1.0 -0.03554991271226789 0.23708358077431466
# Object creation:
# Unweighted network. Weights initialized as 1.
#   Elapsed time: 0.01 sec.
# Initial community structure without projection:
# Initial modularity:  0.41985
#   Elapsed time: 0.00 sec.
# Matrix computation:
#   Elapsed time: 0.01 sec.
# BRIM:
# 0.42065
# 0.42065
#   Elapsed time: 0.00 sec.
# 3 0.7960358056265985 -0.009259259259259259 0.19842810200042277
# Object creation:
# Unweighted network. Weights initialized as 1.
#   Elapsed time: 0.01 sec.
# Initial community structure without projection:
# Initial modularity:  0.3530375
#   Elapsed time: 0.00 sec.
# Matrix computation:
#   Elapsed time: 0.02 sec.
# BRIM:
# 0.3698
# 0.3718
# 0.3718
#   Elapsed time: 0.00 sec.
# 3 0.7492795389048992 -0.031069827033952595 0.20658342792281498
# Object creation:
# Unweighted network. Weights initialized as 1.
#   Elapsed time: 0.01 sec.
# Initial community structure without projection:
# Initial modularity:  0.4004875000000001
#   Elapsed time: 0.00 sec.
# Matrix computation:
#   Elapsed time: 0.01 sec.
# BRIM:
# 0.4011
# 0.4011
#   Elapsed time: 0.00 sec.
# 2 1.0 -0.03111111111111111 0.2721072796934866
# Object creation:
# Unweighted network. Weights initialized as 1.
#   Elapsed time: 0.01 sec.
# Initial community structure without projection:
# Initial modularity:  0.41288749999999996
#   Elapsed time: 0.00 sec.
# Matrix computation:
#   Elapsed time: 0.01 sec.
# BRIM:
# 0.41290000000000004
# 0.41290000000000004
#   Elapsed time: 0.00 sec.
# 2 1.0 -0.03111111111111111 0.2721072796934866
# Object creation:
# Unweighted network. Weights initialized as 1.
#   Elapsed time: 0.01 sec.
# Initial community structure without projection:
# Initial modularity:  0.38545
#   Elapsed time: 0.00 sec.
# Matrix computation:
#   Elapsed time: 0.01 sec.
# BRIM:
# 0.39440000000000003
# 0.39440000000000003
#   Elapsed time: 0.00 sec.
# 3 0.8333333333333334 -0.029092071611253198 0.2074982224869809
# Object creation:
# Unweighted network. Weights initialized as 1.
#   Elapsed time: 0.01 sec.
# Initial community structure without projection:
# Initial modularity:  0.3916625
#   Elapsed time: 0.00 sec.
# Matrix computation:
#   Elapsed time: 0.01 sec.
# BRIM:
# 0.392125
# 0.392125
#   Elapsed time: 0.00 sec.
# 3 0.9354120267260579 -0.005407124681933842 0.3087042399371009
# Object creation:
# Unweighted network. Weights initialized as 1.
#   Elapsed time: 0.01 sec.
# Initial community structure without projection:
# Initial modularity:  0.38218750000000007
#   Elapsed time: 0.00 sec.
# Matrix computation:
#   Elapsed time: 0.01 sec.
# BRIM:
# 0.3829
# 0.3829
#   Elapsed time: 0.00 sec.
# 2 1.0 -0.03554991271226789 0.23708358077431466
# Object creation:
# Unweighted network. Weights initialized as 1.
#   Elapsed time: 0.01 sec.
# Initial community structure without projection:
# Initial modularity:  0.4134875
#   Elapsed time: 0.00 sec.
# Matrix computation:
#   Elapsed time: 0.01 sec.
# BRIM:
# 0.41379999999999995
# 0.41379999999999995
#   Elapsed time: 0.00 sec.
# 2 1.0 -0.03111111111111111 0.2721072796934866
# Object creation:
# Unweighted network. Weights initialized as 1.
#   Elapsed time: 0.01 sec.
# Initial community structure without projection:
# Initial modularity:  0.38746250000000004
#   Elapsed time: 0.00 sec.
# Matrix computation:
#   Elapsed time: 0.01 sec.
# BRIM:
# 0.38785000000000003
# 0.38785000000000003
#   Elapsed time: 0.00 sec.
# 3 0.8659333652160051 -0.03736825295432769 0.21928594749275002
# Object creation:
# Unweighted network. Weights initialized as 1.
#   Elapsed time: 0.00 sec.
# Initial community structure without projection:
# Initial modularity:  0.3736374999999999
#   Elapsed time: 0.00 sec.
# Matrix computation:
#   Elapsed time: 0.01 sec.
# BRIM:
# 0.37474999999999997
# 0.37474999999999997
#   Elapsed time: 0.00 sec.
# 3 0.637383776851555 -0.04035874439461883 0.15634803025345934
# Object creation:
# Unweighted network. Weights initialized as 1.
#   Elapsed time: 0.00 sec.
# Initial community structure without projection:
# Initial modularity:  0.3943875
#   Elapsed time: 0.00 sec.
# Matrix computation:
#   Elapsed time: 0.01 sec.
# BRIM:
# 0.39449999999999996
# 0.39449999999999996
#   Elapsed time: 0.00 sec.
# 2 1.0 -0.03111111111111111 0.2721072796934866
# Object creation:
# Unweighted network. Weights initialized as 1.
#   Elapsed time: 0.01 sec.
# Initial community structure without projection:
# Initial modularity:  0.41048750000000006
#   Elapsed time: 0.00 sec.
# Matrix computation:
#   Elapsed time: 0.01 sec.
# BRIM:
# 0.41080000000000005
# 0.41080000000000005
#   Elapsed time: 0.00 sec.
# 2 1.0 -0.03111111111111111 0.2721072796934866
# Object creation:
# Unweighted network. Weights initialized as 1.
#   Elapsed time: 0.01 sec.
# Initial community structure without projection:
# Initial modularity:  0.4049999999999999
#   Elapsed time: 0.00 sec.
# Matrix computation:
#   Elapsed time: 0.01 sec.
# BRIM:
# 0.4284
# 0.4284
#   Elapsed time: 0.00 sec.
# 2 1.0 -0.03111111111111111 0.2721072796934866
# Object creation:
# Unweighted network. Weights initialized as 1.
#   Elapsed time: 0.01 sec.
# Initial community structure without projection:
# Initial modularity:  0.4046875
#   Elapsed time: 0.00 sec.
# Matrix computation:
#   Elapsed time: 0.01 sec.
# BRIM:
# 0.40469999999999995
# 0.40469999999999995
#   Elapsed time: 0.00 sec.
# 2 1.0 -0.03111111111111111 0.2721072796934866
# Object creation:
# Unweighted network. Weights initialized as 1.
#   Elapsed time: 0.00 sec.
# Initial community structure without projection:
# Initial modularity:  0.41488749999999996
#   Elapsed time: 0.00 sec.
# Matrix computation:
#   Elapsed time: 0.01 sec.
# BRIM:
# 0.4151999999999999
# 0.4151999999999999
#   Elapsed time: 0.00 sec.
# 2 1.0 -0.03111111111111111 0.2721072796934866
# Object creation:
# Unweighted network. Weights initialized as 1.
#   Elapsed time: 0.01 sec.
# Initial community structure without projection:
# Initial modularity:  0.4134874999999999
#   Elapsed time: 0.00 sec.
# Matrix computation:
#   Elapsed time: 0.01 sec.
# BRIM:
# 0.4135
# 0.4135
#   Elapsed time: 0.00 sec.
# 2 1.0 -0.03111111111111111 0.2721072796934866
# Object creation:
# Unweighted network. Weights initialized as 1.
#   Elapsed time: 0.00 sec.
# Initial community structure without projection:
# Initial modularity:  0.40680000000000005
#   Elapsed time: 0.00 sec.
# Matrix computation:
#   Elapsed time: 0.01 sec.
# BRIM:
# 0.40685
# 0.40685
#   Elapsed time: 0.00 sec.
# 2 1.0 -0.03111111111111111 0.2721072796934866
# Object creation:
# Unweighted network. Weights initialized as 1.
#   Elapsed time: 0.01 sec.
# Initial community structure without projection:
# Initial modularity:  0.42288749999999997
#   Elapsed time: 0.00 sec.
# Matrix computation:
#   Elapsed time: 0.01 sec.
# BRIM:
# 0.42350000000000004
# 0.42350000000000004
#   Elapsed time: 0.00 sec.
# 2 1.0 -0.03111111111111111 0.2721072796934866
# Object creation:
# Unweighted network. Weights initialized as 1.
#   Elapsed time: 0.00 sec.
# Initial community structure without projection:
# Initial modularity:  0.41000000000000003
#   Elapsed time: 0.00 sec.
# Matrix computation:
#   Elapsed time: 0.01 sec.
# BRIM:
# 0.41045
# 0.41045
#   Elapsed time: 0.00 sec.
# 2 1.0 -0.03111111111111111 0.2721072796934866
# Object creation:
# Unweighted network. Weights initialized as 1.
#   Elapsed time: 0.01 sec.
# Initial community structure without projection:
# Initial modularity:  0.3628875
#   Elapsed time: 0.00 sec.
# Matrix computation:
#   Elapsed time: 0.01 sec.
# BRIM:
# 0.37177499999999997
# 0.37177499999999997
#   Elapsed time: 0.00 sec.
# 3 0.8333333333333334 -0.035384124960153016 0.22617378780604896
# Object creation:
# Unweighted network. Weights initialized as 1.
#   Elapsed time: 0.00 sec.
# Initial community structure without projection:
# Initial modularity:  0.3898375
#   Elapsed time: 0.00 sec.
# Matrix computation:
#   Elapsed time: 0.01 sec.
# BRIM:
# 0.39239999999999997
# 0.39239999999999997
#   Elapsed time: 0.00 sec.
# 3 0.7541979849672157 -0.03008 0.21829509835971
# Object creation:
# Unweighted network. Weights initialized as 1.
#   Elapsed time: 0.01 sec.
# Initial community structure without projection:
# Initial modularity:  0.40438750000000007
#   Elapsed time: 0.00 sec.
# Matrix computation:
#   Elapsed time: 0.01 sec.
# BRIM:
# 0.4072
# 0.4072
#   Elapsed time: 0.00 sec.
# 2 1.0 -0.03111111111111111 0.2721072796934866

# %%
# # Contestant Techniques 
# from sklearn.cluster import AgglomerativeClustering
# import numpy
# from igraph import *
# import igraph
# import random
# import numpy as np
# import pandas as pd
# from sklearn.metrics.cluster import adjusted_rand_score

# path = "/Users/mcdicjh2/Desktop/gecco22/"

# for it in range(0,30):

#     # Read in graph and associated data
#     g_org = Graph.Read_Edgelist(path+"Graph"+str(it)+".dat")
#     truth = pd.read_csv(path+"Graph"+str(it)+".truth.dat", sep=',',header=None)
#     groundtruth=truth.iloc[:, 1].values.tolist()
#     v = pd.read_csv(path+"Graph"+str(it)+".vertices.dat", sep=',',header=None)
#     vertices=v.iloc[:, 1].values.tolist()
#     edges = g_org.get_edgelist()
    
#     # Generate Bipartite graph
#     g3 = Graph.Bipartite(vertices, edges)
#     n_var = len(vertices)
#     lower = vertices.count(0) 


#     c= g3.clusters()  # This should always be 1 one now
#     g1, g2 = g3.bipartite_projection(multiplicity=True)

#     # Run Multi-Level algorithm (not implemented in igraph package)
#     multilevel_result = pd.DataFrame(columns=['k','m','m1','m2','ari'])
#     test1 = g1.community_multilevel()
#     test2 = g2.community_multilevel()

#     # Cluster assignment from each projection
#     assignment=test1.membership+test2.membership


#     k1=max(test1.membership)+1
#     k2=max(test2.membership)+1
#     d = numpy.zeros(shape=(k1+k2,k1+k2))


#     # Calculate dissimilarity matrix between communities
#     for ei in range(0,len(edges)):
#         #print(edges[ei],edges[ei][0],edges[ei][1])
#         index1=assignment[edges[ei][0]]
#         index2=k1+assignment[edges[ei][1]]
#        # print(index1,index2)
#         d[index1][index2]=d[index1][index2]+1
#         d[index2][index1]=d[index2][index1]+1

#     for d1 in range(0,k1+k2):
#         for d2 in range(0,k1+k2):
#             d[d1][d2] = 1.0/(1.0+d[d1][d2])
#         d[d1][d1] = 0


#     ctr=0
#     for k in range(len(c),k1+k2):
  
#         # Run hierarchical clustering on communities
#         clustering = AgglomerativeClustering(n_clusters=k,linkage='average',affinity='precomputed').fit(d)
#         labels = clustering.labels_


#         newlabels = np.empty(n_var)
#         newlabels.fill(0)

#         for v in range(0,lower):
#             newlabels[v] = labels[assignment[v]]

#         for v in range(lower,n_var):
#             newlabels[v] = labels[k1+assignment[v]]


#         m3 = g3.modularity(newlabels)
#         m1 = g1.modularity(newlabels[0:lower],weights=g1.es['weight'])
#         m2 = g2.modularity(newlabels[lower:n_var],weights=g2.es['weight'])
#         ari = adjusted_rand_score(groundtruth,newlabels)
#         multilevel_result.loc[ctr] = k, m3, m1, m2, ari
#         ctr=ctr+1


#     # Run FastGreedy and Comunity Edge for comparison

#     communityedge_result = pd.DataFrame(columns=['k','m','m1','m2','ari'])
#     communityedge_res = g3.community_edge_betweenness()

#     walktrap_result = pd.DataFrame(columns=['k','m','m1','m2','ari'])
#     walktrap_res = g3.community_walktrap()

#     fastgreedy_result = pd.DataFrame(columns=['k','m','m1','m2','ari'])
#     fastgreedy_res = g3.community_fastgreedy()


   
#     for i in range (0,1):
#         for k in range(len(c),min(len(c)+15,n_var)):
            
            
#             test = fastgreedy_res.as_clustering(k)
#             m3 = g3.modularity(test)

#             m1 = g1.modularity(test.membership[0:lower],weights=g1.es['weight'])
#             m2 = g2.modularity(test.membership[lower:n_var],weights=g2.es['weight'])

#             ari = adjusted_rand_score(groundtruth,test.membership)
#             fastgreedy_result.loc[i*30+k] = k, m3, m1, m2, ari

#             test = communityedge_res.as_clustering(k)
#             m3 = g3.modularity(test)

#             m1 = g1.modularity(test.membership[0:lower],weights=g1.es['weight'])
#             m2 = g2.modularity(test.membership[lower:n_var],weights=g2.es['weight'])

#             ari = adjusted_rand_score(groundtruth,test.membership)
#             communityedge_result.loc[i*30+k] = k, m3, m1, m2, ari

#             test = walktrap_res.as_clustering(k)
#             m3 = g3.modularity(test)

#             m1 = g1.modularity(test.membership[0:lower],weights=g1.es['weight'])
#             m2 = g2.modularity(test.membership[lower:n_var],weights=g2.es['weight'])

#             ari = adjusted_rand_score(groundtruth,test.membership)
#             walktrap_result.loc[i*30+k] = k, m3, m1, m2, ari
        
#     multilevel_result.to_csv(path+"Graph"+str(it)+".multilevel.csv")
#     communityedge_result.to_csv(path+"Graph"+str(it)+".communityedge.csv")
#     walktrap_result.to_csv(path+"Graph"+str(it)+".walktrap.csv")
#     fastgreedy_result.to_csv(path+"Graph"+str(it)+".fastgreedy.csv")

# %%
# # Yet another contestant technique
# # Use of BRIM package for comparison

# import condor
# import pandas as pd
# from igraph import Graph

# for it in range(0,30):


#     # Read in graph and associated data
#     g_org = Graph.Read_Edgelist(path+"Graph"+str(it)+".dat")
#     truth = pd.read_csv(path+"Graph"+str(it)+".truth.dat", sep=',',header=None)
#     groundtruth=truth.iloc[:, 1].values.tolist()
#     v = pd.read_csv(path+"Graph"+str(it)+".vertices.dat", sep=',',header=None)
#     vertices=v.iloc[:, 1].values.tolist()
#     edges = g_org.get_edgelist()

#     g3 = Graph.Bipartite(vertices, edges)
#     n_var = len(vertices)
#     lower = vertices.count(0)

#     g1, g2 = g3.bipartite_projection(multiplicity=True)
    
#     el = g3.get_edgelist()
#     net = pd.DataFrame(el)



#     brim_result = pd.DataFrame(columns=['k','ari','m1','m2','m'])

#     for i in range (0,1):

#         co = condor.condor_object(net)
#         co = condor.initial_community(co)
#         co = condor.brim(co)

#         n_l = vertices.count(0)
        
#         groundtruth1 = groundtruth[0:n_l]
#         groundtruth2 = groundtruth[n_l:n_var]
        

#         output1=co["reg_memb"]
#         output1=output1["com"].tolist()
#         output2 = co["tar_memb"]
#         output2=output2["com"].tolist()

        
        
#         ari = adjusted_rand_score(groundtruth1,output2)
#         ari2 = adjusted_rand_score(groundtruth2,output1)
#         output3=output2+output1
#         #print(output)
#         ari3 = adjusted_rand_score(groundtruth,output3)
#         print(max(output3)+1,ari,ari2,ari3)

#         m = g3.modularity(output3)
#         m1 = g1.modularity(output2,weights=g1.es['weight'])#
#         m2 = g2.modularity(output1,weights=g2.es['weight'])

#         k = (max(output3)+1)
#         brim_result.loc[i] = k, ari3, m1, m2, m
        
#     brim_result.to_csv(path+"Graph"+str(it)+".brim.csv")
